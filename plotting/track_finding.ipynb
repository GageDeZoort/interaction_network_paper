# %%
import os
import sys
import random
import time
import argparse
sys.path.append('../')

import pickle
import yaml
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from sklearn.cluster import DBSCAN

from models.dataset import Dataset
from models.interaction_network import InteractionNetwork
from models.graph import Graph, save_graphs, load_graph

# %%
def calc_dphi(phi1, phi2):
    """Computes phi2-phi1 given in range [-pi,pi]"""
    dphi = phi2 - phi1
    dphi[dphi > np.pi] -= 2*np.pi
    dphi[dphi < -np.pi] += 2*np.pi
    return dphi

def calc_eta(r, z):
    theta = np.arctan2(r, z)
    return -1. * np.log(np.tan(theta / 2.))

# %%
pt_cut = 1
use_cuda = False
construction = 'heptrkx_plus'
epoch = 48
disc = 0.3
model = "../trained_models/train1_40hu_{}_epoch{}_{}GeV.pt".format(construction, epoch, pt_cut)
print("model={0}".format(model))

# load in test graph paths
graph_indir = "../../hitgraphs_2/{}_{}/".format(construction, pt_cut)
graph_files = np.array(os.listdir(graph_indir))

device = torch.device("cuda" if use_cuda else "cpu")

train_kwargs = {'batch_size': 1}
test_kwargs = {'batch_size': 1}

n_graphs = len(graph_files)
IDs = np.arange(n_graphs)
#np.random.shuffle(IDs)
partition = {'test':  graph_files[IDs[1000:1400]]}

params = {'batch_size': 1, 'shuffle': True, 'num_workers': 6}
test_set = Dataset(graph_indir, partition['test'])
test_loader = torch.utils.data.DataLoader(test_set, **params)

interaction_network = InteractionNetwork(3, 4, 4)
interaction_network.load_state_dict(torch.load(model, map_location=torch.device('cpu')))
interaction_network.eval()
# Out:
# model=../trained_models/train1_40hu_heptrkx_plus_epoch48_1GeV.pt
# InteractionNetwork(
#   (phi_R1): RelationalModel(
#     (layers): Sequential(
#       (0): Linear(in_features=10, out_features=40, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=40, out_features=4, bias=True)
#     )
#   )
#   (phi_R2): RelationalModel(
#     (layers): Sequential(
#       (0): Linear(in_features=10, out_features=40, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=40, out_features=1, bias=True)
#     )
#   )
#   (phi_O): ObjectModel(
#     (layers): Sequential(
#       (0): Linear(in_features=7, out_features=40, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=40, out_features=3, bias=True)
#     )
#   )
# )

# %%
good_eff, tight_eff = [], []
with torch.no_grad():
    counter = 0
    for data, target in test_loader:
        
        # grab data and targets 
        X, Ra = data['X'].float().to(device), data['Ra'].float().to(device)
        Ri, Ro = data['Ri'].float().to(device), data['Ro'].float().to(device)
        pids = target['pid'][0].to(device)
        target = target['y'].to(device)
        
        # inference, loss calculation
        output = interaction_network(X, Ra.float(), Ri.float(), Ro.float())
        test_loss = F.binary_cross_entropy(output.squeeze(2), target,
                                           reduction='mean').item()
        accuracy = torch.sum(((target==1).squeeze() &
                              (output>disc).squeeze()) |
                             ((target==0).squeeze() &
                              (output<disc).squeeze())).float()/target.shape[1]

        print('loss={}, acc={}'.format(test_loss, accuracy))

        # shape up output, calculate true edges 
        output = output.squeeze()
        true_edges = (output>disc).squeeze()
        probs = torch.transpose(torch.unsqueeze(output, dim=0), 0, 1)
        
        # count hits per pid in each event, add indices to hits
        n_particles = len(np.unique(pids))
        pid_counts = {p.item(): torch.sum(pids==p).item() for p in pids}
        pid_label_map = {p.item(): -5 for p in pids}
        hit_idx = torch.unsqueeze(torch.arange(X[0].shape[1]), dim=0)
        X = torch.cat((hit_idx.float(), X[0]), dim=0)
    
        # separate segments into incoming and outgoing hit positions 
        feats_o = torch.matmul(Ro[0], torch.transpose(X, dim0=0, dim1=1))
        feats_o = torch.cat((feats_o, probs), dim=1)
        feats_o = feats_o[true_edges]
        feats_i = torch.matmul(Ri[0], torch.transpose(X, dim0=0, dim1=1))
        feats_i = torch.cat((feats_i, probs), dim=1)
        feats_i = feats_i[true_edges]
        
        # geometric quantities --> distance calculation 
        r_o, phi_o, z_o = feats_o[:,1], feats_o[:,2], feats_o[:,3]
        eta_o = calc_eta(r_o, z_o)
        r_i, phi_i, z_i = feats_i[:,1], feats_i[:,2], feats_i[:,3]
        eta_i = calc_eta(r_i, z_i)
        dphi, deta = calc_dphi(phi_o, phi_i), eta_i-eta_o
        distances = torch.sqrt((r_i*torch.cos(np.pi*phi_i) - r_o*torch.cos(np.pi*phi_o))**2 +
                               (r_i*torch.sin(np.pi*phi_i) - r_i*torch.sin(np.pi*phi_i))**2 +
                               (z_i-z_o)**2)
        #distances = torch.sqrt(dphi**2 + deta**2)
        
        dist_matrix = 10*torch.ones(X.shape[1], X.shape[1])
        for h in range(len(feats_i)):
            dist_matrix[int(feats_o[h][0])][int(feats_i[h][0])] = distances[h]
            
        # run DBScan
        eps, min_pts = 0.38, 1
        clustering = DBSCAN(eps=eps, min_samples=min_pts,
                            metric='precomputed').fit(dist_matrix)
        labels = clustering.labels_
        
        # count reconstructed particles from hit clusters 
        good_clusters, tight_clusters = 0, 0
        for label in np.unique(labels):  
            if label==-1: continue # ignore noise 
                
            # grab pids corresponding to hit cluster labels
            label_pids = pids[labels==label]
            main_pid = np.bincount(label_pids).argmax() # most frequent pid in cluster
            
            # fraction of hits with the most common pid 
            hit_fraction = len(label_pids[label_pids==main_pid])/len(label_pids)
            
            # check if pid has been mapped to cluster before 
            previous_label = pid_label_map[main_pid]
            if (previous_label > -1):
                print('label', label, 'mapped to duplicate particle')
                hit_fraction = 0
                
            pid_label_map[main_pid] = label
            if hit_fraction > 0.99:
                good_clusters+=1
                pid = label_pids[0].item()
                if pid_counts[pid] == len(label_pids):
                    tight_clusters += 1

        good_eff.append(good_clusters/n_particles)
        tight_eff.append(tight_clusters/n_particles)
        print("GOOD: {}/{}={}".format(good_clusters, n_particles, good_clusters/n_particles))
        print("TIGHT: {}/{}={}".format(tight_clusters, n_particles, tight_clusters/n_particles))
        
        counter += 1
        if (counter > 10): break

print("Good Eff: {}+/-{}", np.mean(good_eff), np.std(good_eff))
print("Tight Eff: {}+/-{}", np.mean(tight_eff), np.std(tight_eff))
# Out:
# loss=0.007400191389024258, acc=0.9971281290054321
# label 74 mapped to duplicate particle
# label 144 mapped to duplicate particle
# label 153 mapped to duplicate particle
# label 165 mapped to duplicate particle
# label 215 mapped to duplicate particle
# label 276 mapped to duplicate particle
# label 337 mapped to duplicate particle
# label 359 mapped to duplicate particle
# label 389 mapped to duplicate particle
# label 421 mapped to duplicate particle
# label 426 mapped to duplicate particle
# label 485 mapped to duplicate particle
# label 522 mapped to duplicate particle
# label 540 mapped to duplicate particle
# label 588 mapped to duplicate particle
# label 591 mapped to duplicate particle
# label 650 mapped to duplicate particle
# label 692 mapped to duplicate particle
# label 708 mapped to duplicate particle
# label 724 mapped to duplicate particle
# label 787 mapped to duplicate particle
# label 801 mapped to duplicate particle
# label 824 mapped to duplicate particle
# label 847 mapped to duplicate particle
# label 850 mapped to duplicate particle
# label 923 mapped to duplicate particle
# label 938 mapped to duplicate particle
# label 975 mapped to duplicate particle
# label 991 mapped to duplicate particle
# label 1130 mapped to duplicate particle
# label 1149 mapped to duplicate particle
# GOOD: 1087/1172=0.9274744027303754
# TIGHT: 1007/1172=0.8592150170648464
# loss=0.00396382063627243, acc=0.9982171654701233
# label 1 mapped to duplicate particle
# label 8 mapped to duplicate particle
# label 33 mapped to duplicate particle
# label 40 mapped to duplicate particle
# label 65 mapped to duplicate particle
# label 85 mapped to duplicate particle
# label 101 mapped to duplicate particle
# label 143 mapped to duplicate particle
# label 213 mapped to duplicate particle
# label 236 mapped to duplicate particle
# label 307 mapped to duplicate particle
# label 352 mapped to duplicate particle
# label 486 mapped to duplicate particle
# label 585 mapped to duplicate particle
# label 602 mapped to duplicate particle
# label 626 mapped to duplicate particle
# label 644 mapped to duplicate particle
# label 657 mapped to duplicate particle
# label 666 mapped to duplicate particle
# label 671 mapped to duplicate particle
# label 674 mapped to duplicate particle
# label 682 mapped to duplicate particle
# label 685 mapped to duplicate particle
# label 694 mapped to duplicate particle
# label 715 mapped to duplicate particle
# label 733 mapped to duplicate particle
# label 845 mapped to duplicate particle
# label 934 mapped to duplicate particle
# label 966 mapped to duplicate particle
# GOOD: 995/1050=0.9476190476190476
# TIGHT: 926/1050=0.8819047619047619
# loss=0.006403207778930664, acc=0.9975296258926392
# label 26 mapped to duplicate particle
# label 52 mapped to duplicate particle
# label 69 mapped to duplicate particle
# label 117 mapped to duplicate particle
# label 159 mapped to duplicate particle
# label 163 mapped to duplicate particle
# label 298 mapped to duplicate particle
# label 302 mapped to duplicate particle
# label 337 mapped to duplicate particle
# label 360 mapped to duplicate particle
# label 365 mapped to duplicate particle
# label 386 mapped to duplicate particle
# label 398 mapped to duplicate particle
# label 454 mapped to duplicate particle
# label 524 mapped to duplicate particle
# label 581 mapped to duplicate particle
# label 589 mapped to duplicate particle
# label 632 mapped to duplicate particle
# label 635 mapped to duplicate particle
# label 642 mapped to duplicate particle
# label 654 mapped to duplicate particle
# label 657 mapped to duplicate particle
# label 671 mapped to duplicate particle
# label 705 mapped to duplicate particle
# label 771 mapped to duplicate particle
# label 794 mapped to duplicate particle
# label 845 mapped to duplicate particle
# label 870 mapped to duplicate particle
# label 880 mapped to duplicate particle
# label 889 mapped to duplicate particle
# label 936 mapped to duplicate particle
# label 970 mapped to duplicate particle
# label 1026 mapped to duplicate particle
# label 1029 mapped to duplicate particle
# label 1074 mapped to duplicate particle
# GOOD: 1060/1123=0.943900267141585
# TIGHT: 983/1123=0.8753339269813001
# loss=0.005252435803413391, acc=0.9977911710739136
# label 32 mapped to duplicate particle
# label 58 mapped to duplicate particle
# label 140 mapped to duplicate particle
# label 178 mapped to duplicate particle
# label 292 mapped to duplicate particle
# label 388 mapped to duplicate particle
# label 391 mapped to duplicate particle
# label 423 mapped to duplicate particle
# label 471 mapped to duplicate particle
# label 583 mapped to duplicate particle
# label 590 mapped to duplicate particle
# label 603 mapped to duplicate particle
# label 622 mapped to duplicate particle
# label 828 mapped to duplicate particle
# label 878 mapped to duplicate particle
# label 888 mapped to duplicate particle
# label 901 mapped to duplicate particle
# label 932 mapped to duplicate particle
# label 974 mapped to duplicate particle
# label 984 mapped to duplicate particle
# label 1000 mapped to duplicate particle
# label 1004 mapped to duplicate particle
# label 1025 mapped to duplicate particle
# label 1057 mapped to duplicate particle
# label 1095 mapped to duplicate particle
# label 1239 mapped to duplicate particle
# label 1241 mapped to duplicate particle
# label 1261 mapped to duplicate particle
# label 1263 mapped to duplicate particle
# label 1298 mapped to duplicate particle
# GOOD: 1264/1348=0.9376854599406528
# TIGHT: 1169/1348=0.8672106824925816
# loss=0.006073930766433477, acc=0.9971596002578735
# label 2 mapped to duplicate particle
# label 4 mapped to duplicate particle
# label 7 mapped to duplicate particle
# label 9 mapped to duplicate particle
# label 11 mapped to duplicate particle
# label 15 mapped to duplicate particle
# label 42 mapped to duplicate particle
# label 159 mapped to duplicate particle
# label 176 mapped to duplicate particle
# label 338 mapped to duplicate particle
# label 406 mapped to duplicate particle
# label 418 mapped to duplicate particle
# label 536 mapped to duplicate particle
# label 547 mapped to duplicate particle
# label 606 mapped to duplicate particle
# label 632 mapped to duplicate particle
# label 656 mapped to duplicate particle
# label 683 mapped to duplicate particle
# label 743 mapped to duplicate particle
# label 756 mapped to duplicate particle
# label 784 mapped to duplicate particle
# label 852 mapped to duplicate particle
# label 905 mapped to duplicate particle
# label 907 mapped to duplicate particle
# label 919 mapped to duplicate particle
# label 929 mapped to duplicate particle
# label 984 mapped to duplicate particle
# GOOD: 940/997=0.9428284854563691
# TIGHT: 864/997=0.8665997993981945
# loss=0.006323954090476036, acc=0.9969989061355591
# label 43 mapped to duplicate particle
# label 139 mapped to duplicate particle
# label 141 mapped to duplicate particle
# label 199 mapped to duplicate particle
# label 267 mapped to duplicate particle
# label 303 mapped to duplicate particle
# label 307 mapped to duplicate particle
# label 363 mapped to duplicate particle
# label 381 mapped to duplicate particle
# label 411 mapped to duplicate particle
# label 480 mapped to duplicate particle
# label 482 mapped to duplicate particle
# label 523 mapped to duplicate particle
# label 582 mapped to duplicate particle
# label 610 mapped to duplicate particle
# label 679 mapped to duplicate particle
# label 718 mapped to duplicate particle
# label 727 mapped to duplicate particle
# label 802 mapped to duplicate particle
# label 815 mapped to duplicate particle
# label 823 mapped to duplicate particle
# label 898 mapped to duplicate particle
# label 972 mapped to duplicate particle
# label 977 mapped to duplicate particle
# label 1013 mapped to duplicate particle
# GOOD: 975/1032=0.9447674418604651
# TIGHT: 910/1032=0.8817829457364341
# loss=0.006667930632829666, acc=0.9976374506950378
# label 8 mapped to duplicate particle
# label 36 mapped to duplicate particle
# label 38 mapped to duplicate particle
# label 59 mapped to duplicate particle
# label 65 mapped to duplicate particle
# label 67 mapped to duplicate particle
# label 69 mapped to duplicate particle
# label 120 mapped to duplicate particle
# label 207 mapped to duplicate particle
# label 260 mapped to duplicate particle
# label 271 mapped to duplicate particle
# label 292 mapped to duplicate particle
# label 400 mapped to duplicate particle
# label 513 mapped to duplicate particle
# label 584 mapped to duplicate particle
# label 612 mapped to duplicate particle
# label 649 mapped to duplicate particle
# label 669 mapped to duplicate particle
# label 708 mapped to duplicate particle
# label 739 mapped to duplicate particle
# label 757 mapped to duplicate particle
# label 776 mapped to duplicate particle
# label 810 mapped to duplicate particle
# label 813 mapped to duplicate particle
# label 817 mapped to duplicate particle
# label 866 mapped to duplicate particle
# label 872 mapped to duplicate particle
# label 879 mapped to duplicate particle
# label 966 mapped to duplicate particle
# label 971 mapped to duplicate particle
# GOOD: 935/985=0.949238578680203
# TIGHT: 865/985=0.8781725888324873
# loss=0.0052935294806957245, acc=0.9980215430259705
# label 64 mapped to duplicate particle
# label 99 mapped to duplicate particle
# label 108 mapped to duplicate particle
# label 133 mapped to duplicate particle
# label 243 mapped to duplicate particle
# label 250 mapped to duplicate particle
# label 330 mapped to duplicate particle
# label 332 mapped to duplicate particle
# label 367 mapped to duplicate particle
# label 376 mapped to duplicate particle
# label 435 mapped to duplicate particle
# label 457 mapped to duplicate particle
# label 462 mapped to duplicate particle
# label 499 mapped to duplicate particle
# label 536 mapped to duplicate particle
# label 572 mapped to duplicate particle
# label 592 mapped to duplicate particle
# label 648 mapped to duplicate particle
# label 740 mapped to duplicate particle
# label 816 mapped to duplicate particle
# label 856 mapped to duplicate particle
# label 889 mapped to duplicate particle
# label 932 mapped to duplicate particle
# label 1058 mapped to duplicate particle
# label 1079 mapped to duplicate particle
# label 1089 mapped to duplicate particle
# GOOD: 1073/1141=0.9404031551270815
# TIGHT: 1004/1141=0.8799298860648553
# loss=0.005848209373652935, acc=0.9978665709495544
# label 3 mapped to duplicate particle
# label 14 mapped to duplicate particle
# label 50 mapped to duplicate particle
# label 64 mapped to duplicate particle
# label 78 mapped to duplicate particle
# label 122 mapped to duplicate particle
# label 126 mapped to duplicate particle
# label 128 mapped to duplicate particle
# label 145 mapped to duplicate particle
# label 158 mapped to duplicate particle
# label 195 mapped to duplicate particle
# label 221 mapped to duplicate particle
# label 250 mapped to duplicate particle
# label 320 mapped to duplicate particle
# label 326 mapped to duplicate particle
# label 334 mapped to duplicate particle
# label 338 mapped to duplicate particle
# label 354 mapped to duplicate particle
# label 375 mapped to duplicate particle
# label 410 mapped to duplicate particle
# label 436 mapped to duplicate particle
# label 447 mapped to duplicate particle
# label 452 mapped to duplicate particle
# label 454 mapped to duplicate particle
# label 464 mapped to duplicate particle
# label 528 mapped to duplicate particle
# label 562 mapped to duplicate particle
# label 568 mapped to duplicate particle
# label 684 mapped to duplicate particle
# label 703 mapped to duplicate particle
# label 759 mapped to duplicate particle
# label 761 mapped to duplicate particle
# label 770 mapped to duplicate particle
# label 772 mapped to duplicate particle
# GOOD: 768/808=0.9504950495049505
# TIGHT: 708/808=0.8762376237623762
# loss=0.006505400873720646, acc=0.9973924160003662
# label 2 mapped to duplicate particle
# label 4 mapped to duplicate particle
# label 116 mapped to duplicate particle
# label 123 mapped to duplicate particle
# label 133 mapped to duplicate particle
# label 180 mapped to duplicate particle
# label 198 mapped to duplicate particle
# label 244 mapped to duplicate particle
# label 377 mapped to duplicate particle
# label 391 mapped to duplicate particle
# label 460 mapped to duplicate particle
# label 462 mapped to duplicate particle
# label 527 mapped to duplicate particle
# label 698 mapped to duplicate particle
# label 715 mapped to duplicate particle
# label 721 mapped to duplicate particle
# label 754 mapped to duplicate particle
# label 759 mapped to duplicate particle
# label 768 mapped to duplicate particle
# label 781 mapped to duplicate particle
# label 783 mapped to duplicate particle
# label 789 mapped to duplicate particle
# label 802 mapped to duplicate particle
# label 809 mapped to duplicate particle
# label 820 mapped to duplicate particle
# label 829 mapped to duplicate particle
# label 889 mapped to duplicate particle
# label 927 mapped to duplicate particle
# label 950 mapped to duplicate particle
# label 954 mapped to duplicate particle
# label 1003 mapped to duplicate particle
# label 1006 mapped to duplicate particle
# label 1016 mapped to duplicate particle
# label 1018 mapped to duplicate particle
# label 1028 mapped to duplicate particle
# label 1032 mapped to duplicate particle
# GOOD: 1012/1065=0.9502347417840376
# TIGHT: 941/1065=0.8835680751173709
# loss=0.004239407368004322, acc=0.998144805431366
# label 151 mapped to duplicate particle
# label 160 mapped to duplicate particle
# label 179 mapped to duplicate particle
# label 204 mapped to duplicate particle
# label 312 mapped to duplicate particle
# label 372 mapped to duplicate particle
# label 410 mapped to duplicate particle
# label 425 mapped to duplicate particle
# label 439 mapped to duplicate particle
# label 447 mapped to duplicate particle
# label 482 mapped to duplicate particle
# label 520 mapped to duplicate particle
# label 543 mapped to duplicate particle
# label 583 mapped to duplicate particle
# label 592 mapped to duplicate particle
# label 633 mapped to duplicate particle
# label 660 mapped to duplicate particle
# label 682 mapped to duplicate particle
# label 701 mapped to duplicate particle
# label 747 mapped to duplicate particle
# label 776 mapped to duplicate particle
# label 784 mapped to duplicate particle
# label 802 mapped to duplicate particle
# label 842 mapped to duplicate particle
# label 875 mapped to duplicate particle
# label 891 mapped to duplicate particle
# label 919 mapped to duplicate particle
# label 920 mapped to duplicate particle
# label 925 mapped to duplicate particle
# label 1106 mapped to duplicate particle
# label 1160 mapped to duplicate particle
# label 1181 mapped to duplicate particle
# label 1221 mapped to duplicate particle
# label 1257 mapped to duplicate particle
# label 1259 mapped to duplicate particle
# label 1263 mapped to duplicate particle
# GOOD: 1228/1300=0.9446153846153846
# TIGHT: 1133/1300=0.8715384615384615
